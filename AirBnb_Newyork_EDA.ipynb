# %% [markdown]
# <a href="https://colab.research.google.com/github/SandipKumar06529/EDA-on-New_York_Airbnb/blob/main/AirBnb_Newyork_EDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import geopandas as gpd

# %%
# Load the datasets from CSV files
calendar_df = pd.read_csv('/content/calendar.csv')
listings_df = pd.read_csv('/content/listings.csv')
reviews_df = pd.read_csv('/content/reviews.csv')

# %%
# Display the first few rows of each dataframe
print(calendar_df.head())
print(listings_df.head())
print(reviews_df.head())
# Out:
#    listing_id        date available   price  adjusted_price  minimum_nights  \
# 0     2992450  2024-09-05         f  $70.00             NaN              28
# 1     2992450  2024-09-06         f  $70.00             NaN              28
# 2     2992450  2024-09-07         f  $70.00             NaN              28
# 3     2992450  2024-09-08         f  $70.00             NaN              28
# 4     2992450  2024-09-09         f  $70.00             NaN              28
#
#    maximum_nights
# 0            1125
# 1            1125
# 2            1125
# 3            1125
# 4            1125
#         id                           listing_url       scrape_id last_scraped  \
# 0  2992450  https://www.airbnb.com/rooms/2992450  20240905032005   2024-09-05
# 1  3820211  https://www.airbnb.com/rooms/3820211  20240905032005   2024-09-05
# 2  5651579  https://www.airbnb.com/rooms/5651579  20240905032005   2024-09-05
# 3  6623339  https://www.airbnb.com/rooms/6623339  20240905032005   2024-09-05
# 4  8035768  https://www.airbnb.com/rooms/8035768  20240905032005   2024-09-05
#
#         source                                              name  \
# 0  city scrape                        Luxury 2 bedroom apartment
# 1  city scrape         Restored Precinct in Center Sq. w/Parking
# 2  city scrape        Large studio apt  by Capital Center & ESP@
# 3  city scrape  Center Sq. Loft in Converted Precinct w/ Parking
# 4  city scrape            Entire Beautiful French Victorian 1884
#
#                                          description  \
# 0  The apartment is located in a quiet neighborho...
# 1  Cozy, cool little 1BR Apt in the heart Albany'...
# 2  Spacious studio with hardwood floors, fully eq...
# 3  Large renovated 1 bedroom apartment in convert...
# 4  Stunningly renovated French Victorian original...
#
#                                neighborhood_overview  \
# 0                                                NaN
# 1  Great restaurants, architecture, walking, peop...
# 2  The neighborhood is very eclectic. We have a v...
# 3  Located in Albany's finest urban neighborhood,...
# 4  There is a Barbershop with 1900' barber chairs...
#
#                                          picture_url   host_id  ...  \
# 0  https://a0.muscache.com/pictures/44627226/0e72...   4621559  ...
# 1  https://a0.muscache.com/pictures/prohost-api/H...  19648678  ...
# 2  https://a0.muscache.com/pictures/b3fc42f3-6e5e...  29288920  ...
# 3  https://a0.muscache.com/pictures/prohost-api/H...  19648678  ...
# 4  https://a0.muscache.com/pictures/103429331/a0a...  42430824  ...
#
#   review_scores_communication review_scores_location review_scores_value  \
# 0                        4.56                   3.22                3.67
# 1                        4.81                   4.82                4.78
# 2                        4.87                   4.76                4.63
# 3                        4.70                   4.80                4.72
# 4                        4.80                   4.74                4.75
#
#   license instant_bookable calculated_host_listings_count  \
# 0     NaN                f                              1
# 1     NaN                f                              4
# 2     NaN                f                              2
# 3     NaN                f                              4
# 4     NaN                f                              2
#
#   calculated_host_listings_count_entire_homes  \
# 0                                           1
# 1                                           4
# 2                                           1
# 3                                           4
# 4                                           1
#
#   calculated_host_listings_count_private_rooms  \
# 0                                            0
# 1                                            0
# 2                                            1
# 3                                            0
# 4                                            1
#
#   calculated_host_listings_count_shared_rooms reviews_per_month
# 0                                           0              0.07
# 1                                           0              2.49
# 2                                           0              3.22
# 3                                           0              2.91
# 4                                           0              0.51
#
# [5 rows x 75 columns]
#    listing_id        id        date  reviewer_id reviewer_name  \
# 0     2992450  15066586  2014-07-01     16827297       Kristen
# 1     2992450  21810844  2014-10-24     22648856   Christopher
# 2     2992450  27434334  2015-03-04        45406         Altay
# 3     2992450  28524578  2015-03-25      5485362          John
# 4     2992450  35913434  2015-06-23     15772025      Jennifer
#
#                                             comments
# 0  Large apartment; nice kitchen and bathroom. Ke...
# 1  This may be a little late, but just to say Ken...
# 2  The apartment was very clean and convenient to...
# 3  Kenneth was ready when I got there and arrange...
# 4  We were pleased to see how 2nd Street and the ...

# %%
# Display initial rows to understand the structure
print(listings_df.head())
# Out:
#         id                           listing_url       scrape_id last_scraped  \
# 0  2992450  https://www.airbnb.com/rooms/2992450  20240905032005   2024-09-05
# 1  3820211  https://www.airbnb.com/rooms/3820211  20240905032005   2024-09-05
# 2  5651579  https://www.airbnb.com/rooms/5651579  20240905032005   2024-09-05
# 3  6623339  https://www.airbnb.com/rooms/6623339  20240905032005   2024-09-05
# 4  8035768  https://www.airbnb.com/rooms/8035768  20240905032005   2024-09-05
#
#         source                                              name  \
# 0  city scrape                        Luxury 2 bedroom apartment
# 1  city scrape         Restored Precinct in Center Sq. w/Parking
# 2  city scrape        Large studio apt  by Capital Center & ESP@
# 3  city scrape  Center Sq. Loft in Converted Precinct w/ Parking
# 4  city scrape            Entire Beautiful French Victorian 1884
#
#                                          description  \
# 0  The apartment is located in a quiet neighborho...
# 1  Cozy, cool little 1BR Apt in the heart Albany'...
# 2  Spacious studio with hardwood floors, fully eq...
# 3  Large renovated 1 bedroom apartment in convert...
# 4  Stunningly renovated French Victorian original...
#
#                                neighborhood_overview  \
# 0                                                NaN
# 1  Great restaurants, architecture, walking, peop...
# 2  The neighborhood is very eclectic. We have a v...
# 3  Located in Albany's finest urban neighborhood,...
# 4  There is a Barbershop with 1900' barber chairs...
#
#                                          picture_url   host_id  ...  \
# 0  https://a0.muscache.com/pictures/44627226/0e72...   4621559  ...
# 1  https://a0.muscache.com/pictures/prohost-api/H...  19648678  ...
# 2  https://a0.muscache.com/pictures/b3fc42f3-6e5e...  29288920  ...
# 3  https://a0.muscache.com/pictures/prohost-api/H...  19648678  ...
# 4  https://a0.muscache.com/pictures/103429331/a0a...  42430824  ...
#
#   review_scores_communication review_scores_location review_scores_value  \
# 0                        4.56                   3.22                3.67
# 1                        4.81                   4.82                4.78
# 2                        4.87                   4.76                4.63
# 3                        4.70                   4.80                4.72
# 4                        4.80                   4.74                4.75
#
#   license instant_bookable calculated_host_listings_count  \
# 0     NaN                f                              1
# 1     NaN                f                              4
# 2     NaN                f                              2
# 3     NaN                f                              4
# 4     NaN                f                              2
#
#   calculated_host_listings_count_entire_homes  \
# 0                                           1
# 1                                           4
# 2                                           1
# 3                                           4
# 4                                           1
#
#   calculated_host_listings_count_private_rooms  \
# 0                                            0
# 1                                            0
# 2                                            1
# 3                                            0
# 4                                            1
#
#   calculated_host_listings_count_shared_rooms reviews_per_month
# 0                                           0              0.07
# 1                                           0              2.49
# 2                                           0              3.22
# 3                                           0              2.91
# 4                                           0              0.51
#
# [5 rows x 75 columns]

# %%
# Display data information to understand data types and null values
listings_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 426 entries, 0 to 425
# Data columns (total 75 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   id                                            426 non-null    int64
#  1   listing_url                                   426 non-null    object
#  2   scrape_id                                     426 non-null    int64
#  3   last_scraped                                  426 non-null    object
#  4   source                                        426 non-null    object
#  5   name                                          426 non-null    object
#  6   description                                   413 non-null    object
#  7   neighborhood_overview                         228 non-null    object
#  8   picture_url                                   426 non-null    object
#  9   host_id                                       426 non-null    int64
#  10  host_url                                      426 non-null    object
#  11  host_name                                     426 non-null    object
#  12  host_since                                    426 non-null    object
#  13  host_location                                 338 non-null    object
#  14  host_about                                    230 non-null    object
#  15  host_response_time                            407 non-null    object
#  16  host_response_rate                            407 non-null    object
#  17  host_acceptance_rate                          412 non-null    object
#  18  host_is_superhost                             419 non-null    object
#  19  host_thumbnail_url                            426 non-null    object
#  20  host_picture_url                              426 non-null    object
#  21  host_neighbourhood                            354 non-null    object
#  22  host_listings_count                           426 non-null    int64
#  23  host_total_listings_count                     426 non-null    int64
#  24  host_verifications                            426 non-null    object
#  25  host_has_profile_pic                          426 non-null    object
#  26  host_identity_verified                        426 non-null    object
#  27  neighbourhood                                 228 non-null    object
#  28  neighbourhood_cleansed                        426 non-null    object
#  29  neighbourhood_group_cleansed                  0 non-null      float64
#  30  latitude                                      426 non-null    float64
#  31  longitude                                     426 non-null    float64
#  32  property_type                                 426 non-null    object
#  33  room_type                                     426 non-null    object
#  34  accommodates                                  426 non-null    int64
#  35  bathrooms                                     400 non-null    float64
#  36  bathrooms_text                                426 non-null    object
#  37  bedrooms                                      421 non-null    float64
#  38  beds                                          398 non-null    float64
#  39  amenities                                     426 non-null    object
#  40  price                                         400 non-null    object
#  41  minimum_nights                                426 non-null    int64
#  42  maximum_nights                                426 non-null    int64
#  43  minimum_minimum_nights                        426 non-null    int64
#  44  maximum_minimum_nights                        426 non-null    int64
#  45  minimum_maximum_nights                        426 non-null    int64
#  46  maximum_maximum_nights                        426 non-null    int64
#  47  minimum_nights_avg_ntm                        426 non-null    float64
#  48  maximum_nights_avg_ntm                        426 non-null    float64
#  49  calendar_updated                              0 non-null      float64
#  50  has_availability                              421 non-null    object
#  51  availability_30                               426 non-null    int64
#  52  availability_60                               426 non-null    int64
#  53  availability_90                               426 non-null    int64
#  54  availability_365                              426 non-null    int64
#  55  calendar_last_scraped                         426 non-null    object
#  56  number_of_reviews                             426 non-null    int64
#  57  number_of_reviews_ltm                         426 non-null    int64
#  58  number_of_reviews_l30d                        426 non-null    int64
#  59  first_review                                  366 non-null    object
#  60  last_review                                   366 non-null    object
#  61  review_scores_rating                          366 non-null    float64
#  62  review_scores_accuracy                        366 non-null    float64
#  63  review_scores_cleanliness                     366 non-null    float64
#  64  review_scores_checkin                         366 non-null    float64
#  65  review_scores_communication                   366 non-null    float64
#  66  review_scores_location                        366 non-null    float64
#  67  review_scores_value                           366 non-null    float64
#  68  license                                       0 non-null      float64
#  69  instant_bookable                              426 non-null    object
#  70  calculated_host_listings_count                426 non-null    int64
#  71  calculated_host_listings_count_entire_homes   426 non-null    int64
#  72  calculated_host_listings_count_private_rooms  426 non-null    int64
#  73  calculated_host_listings_count_shared_rooms   426 non-null    int64
#  74  reviews_per_month                             366 non-null    float64
# dtypes: float64(18), int64(23), object(34)
# memory usage: 249.7+ KB

# %%
# Check for missing values in each column
print("Missing values:\n", listings_df.isnull().sum())
# Out:
# Missing values:
#  id                                               0
# listing_url                                      0
# scrape_id                                        0
# last_scraped                                     0
# source                                           0
#                                                 ..
# calculated_host_listings_count                   0
# calculated_host_listings_count_entire_homes      0
# calculated_host_listings_count_private_rooms     0
# calculated_host_listings_count_shared_rooms      0
# reviews_per_month                               60
# Length: 75, dtype: int64

# %%
# Check descriptive statistics for numerical columns
print(listings_df.describe())
# Out:
#                  id     scrape_id       host_id  host_listings_count  \
# count  4.260000e+02  4.260000e+02  4.260000e+02           426.000000
# mean   6.048429e+17  2.024091e+13  2.226169e+08            23.424883
# std    4.706590e+17  0.000000e+00  1.849103e+08           141.914507
# min    2.992450e+06  2.024091e+13  6.490680e+05             1.000000
# 25%    5.024705e+07  2.024091e+13  4.762598e+07             2.000000
# 50%    7.545450e+17  2.024091e+13  1.855943e+08             4.000000
# 75%    1.014469e+18  2.024091e+13  3.829705e+08             9.000000
# max    1.237964e+18  2.024091e+13  5.808926e+08          1208.000000
#
#        host_total_listings_count  neighbourhood_group_cleansed    latitude  \
# count                 426.000000                           0.0  426.000000
# mean                   40.791080                           NaN   42.658027
# std                   271.701845                           NaN    0.009528
# min                     1.000000                           NaN   42.630660
# 25%                     2.000000                           NaN   42.652615
# 50%                     5.000000                           NaN   42.657435
# 75%                    12.000000                           NaN   42.662873
# max                  2310.000000                           NaN   42.714896
#
#         longitude  accommodates   bathrooms  ...  review_scores_checkin  \
# count  426.000000    426.000000  400.000000  ...             366.000000
# mean   -73.776540      3.579812    1.237500  ...               4.859290
# std      0.019064      2.623777    0.619114  ...               0.252497
# min    -73.876489      1.000000    0.000000  ...               3.000000
# 25%    -73.789038      2.000000    1.000000  ...               4.830000
# 50%    -73.773313      3.000000    1.000000  ...               4.940000
# 75%    -73.763148      4.000000    1.000000  ...               5.000000
# max    -73.738103     16.000000    7.000000  ...               5.000000
#
#        review_scores_communication  review_scores_location  \
# count                   366.000000              366.000000
# mean                      4.871175                4.670656
# std                       0.264593                0.372563
# min                       3.000000                3.000000
# 25%                       4.860000                4.532500
# 50%                       4.950000                4.795000
# 75%                       5.000000                4.930000
# max                       5.000000                5.000000
#
#        review_scores_value  license  calculated_host_listings_count  \
# count           366.000000      0.0                      426.000000
# mean              4.729508      NaN                        5.694836
# std               0.311464      NaN                        6.242610
# min               3.000000      NaN                        1.000000
# 25%               4.670000      NaN                        1.000000
# 50%               4.800000      NaN                        3.000000
# 75%               4.930000      NaN                        8.000000
# max               5.000000      NaN                       25.000000
#
#        calculated_host_listings_count_entire_homes  \
# count                                   426.000000
# mean                                      4.312207
# std                                       6.302096
# min                                       0.000000
# 25%                                       1.000000
# 50%                                       2.000000
# 75%                                       4.000000
# max                                      25.000000
#
#        calculated_host_listings_count_private_rooms  \
# count                                    426.000000
# mean                                       1.377934
# std                                        2.773892
# min                                        0.000000
# 25%                                        0.000000
# 50%                                        0.000000
# 75%                                        1.000000
# max                                       11.000000
#
#        calculated_host_listings_count_shared_rooms  reviews_per_month
# count                                   426.000000         366.000000
# mean                                      0.004695           2.145137
# std                                       0.068438           2.106637
# min                                       0.000000           0.030000
# 25%                                       0.000000           0.572500
# 50%                                       0.000000           1.450000
# 75%                                       0.000000           3.040000
# max                                       1.000000          11.220000
#
# [8 rows x 41 columns]

# %%
# Fill missing values in 'reviews_per_month' with 0, as no reviews means 0 monthly reviews
listings_df['reviews_per_month'] = listings_df['reviews_per_month'].fillna(0)

# %%
# Convert last_review to datetime format
listings_df['last_review'] = pd.to_datetime(listings_df['last_review'], errors='coerce')

# %%
# Remove any duplicate entries from the listings data
listings_df = listings_df.drop_duplicates()

# %%
# Remove any non-numeric characters from 'price', then convert it to a numeric format
listings_df['price'] = listings_df['price'].replace('[\$,]', '', regex=True).astype(float)

# Filter out extreme outliers in price to limit the maximum to $1000
listings_df = listings_df[listings_df['price'] <= 1000]

# verify the changes
listings_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 398 entries, 0 to 425
# Data columns (total 75 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   id                                            398 non-null    int64
#  1   listing_url                                   398 non-null    object
#  2   scrape_id                                     398 non-null    int64
#  3   last_scraped                                  398 non-null    object
#  4   source                                        398 non-null    object
#  5   name                                          398 non-null    object
#  6   description                                   386 non-null    object
#  7   neighborhood_overview                         212 non-null    object
#  8   picture_url                                   398 non-null    object
#  9   host_id                                       398 non-null    int64
#  10  host_url                                      398 non-null    object
#  11  host_name                                     398 non-null    object
#  12  host_since                                    398 non-null    object
#  13  host_location                                 319 non-null    object
#  14  host_about                                    221 non-null    object
#  15  host_response_time                            383 non-null    object
#  16  host_response_rate                            383 non-null    object
#  17  host_acceptance_rate                          386 non-null    object
#  18  host_is_superhost                             391 non-null    object
#  19  host_thumbnail_url                            398 non-null    object
#  20  host_picture_url                              398 non-null    object
#  21  host_neighbourhood                            331 non-null    object
#  22  host_listings_count                           398 non-null    int64
#  23  host_total_listings_count                     398 non-null    int64
#  24  host_verifications                            398 non-null    object
#  25  host_has_profile_pic                          398 non-null    object
#  26  host_identity_verified                        398 non-null    object
#  27  neighbourhood                                 212 non-null    object
#  28  neighbourhood_cleansed                        398 non-null    object
#  29  neighbourhood_group_cleansed                  0 non-null      float64
#  30  latitude                                      398 non-null    float64
#  31  longitude                                     398 non-null    float64
#  32  property_type                                 398 non-null    object
#  33  room_type                                     398 non-null    object
#  34  accommodates                                  398 non-null    int64
#  35  bathrooms                                     398 non-null    float64
#  36  bathrooms_text                                398 non-null    object
#  37  bedrooms                                      398 non-null    float64
#  38  beds                                          396 non-null    float64
#  39  amenities                                     398 non-null    object
#  40  price                                         398 non-null    float64
#  41  minimum_nights                                398 non-null    int64
#  42  maximum_nights                                398 non-null    int64
#  43  minimum_minimum_nights                        398 non-null    int64
#  44  maximum_minimum_nights                        398 non-null    int64
#  45  minimum_maximum_nights                        398 non-null    int64
#  46  maximum_maximum_nights                        398 non-null    int64
#  47  minimum_nights_avg_ntm                        398 non-null    float64
#  48  maximum_nights_avg_ntm                        398 non-null    float64
#  49  calendar_updated                              0 non-null      float64
#  50  has_availability                              395 non-null    object
#  51  availability_30                               398 non-null    int64
#  52  availability_60                               398 non-null    int64
#  53  availability_90                               398 non-null    int64
#  54  availability_365                              398 non-null    int64
#  55  calendar_last_scraped                         398 non-null    object
#  56  number_of_reviews                             398 non-null    int64
#  57  number_of_reviews_ltm                         398 non-null    int64
#  58  number_of_reviews_l30d                        398 non-null    int64
#  59  first_review                                  348 non-null    object
#  60  last_review                                   348 non-null    datetime64[ns]
#  61  review_scores_rating                          348 non-null    float64
#  62  review_scores_accuracy                        348 non-null    float64
#  63  review_scores_cleanliness                     348 non-null    float64
#  64  review_scores_checkin                         348 non-null    float64
#  65  review_scores_communication                   348 non-null    float64
#  66  review_scores_location                        348 non-null    float64
#  67  review_scores_value                           348 non-null    float64
#  68  license                                       0 non-null      float64
#  69  instant_bookable                              398 non-null    object
#  70  calculated_host_listings_count                398 non-null    int64
#  71  calculated_host_listings_count_entire_homes   398 non-null    int64
#  72  calculated_host_listings_count_private_rooms  398 non-null    int64
#  73  calculated_host_listings_count_shared_rooms   398 non-null    int64
#  74  reviews_per_month                             398 non-null    float64
# dtypes: datetime64[ns](1), float64(19), int64(23), object(32)
# memory usage: 236.3+ KB

# %%
# Histogram for price distribution
plt.figure(figsize=(10, 6))
sns.histplot(listings_df['price'], bins=50, kde=True, color='skyblue')
plt.title("Price Distribution of Airbnb Listings")
plt.xlabel("Price")
plt.ylabel("Frequency")
plt.show()

# %%
# Pie chart to show the distribution of different room types
room_type_counts = listings_df['room_type'].value_counts()
plt.figure(figsize=(8, 8))
plt.pie(room_type_counts, labels=room_type_counts.index, autopct='%1.1f%%', startangle=140)
plt.title("Room Type Distribution")
plt.show()

# %%
# Boxplot for price distribution by neighborhood
# Using 'neighbourhood_cleansed' if it contains valid data
if 'neighbourhood_cleansed' in listings_df.columns:
    plt.figure(figsize=(12, 8))
    sns.boxplot(data=listings_df.dropna(subset=['neighbourhood_cleansed']), x='neighbourhood_cleansed', y='price')
    plt.ylim(0, 500)  # Set y-axis limit to focus on the main price range
    plt.grid(axis='y', linestyle='--', alpha=0.7)
    plt.title("Price Distribution by Neighborhood")
    plt.xlabel("Neighborhood", fontsize=14, fontweight='bold')
    plt.ylabel("Price", fontsize=14, fontweight='bold')
    plt.xticks(rotation=90, ha ='center')  # Rotate x-axis labels for better readability
    plt.tight_layout()
    plt.show()

# %%
# Count plot for room type across neighborhoods
plt.figure(figsize=(10, 6))
sns.countplot(data=listings_df.dropna(subset=['neighbourhood_cleansed']),
              x='neighbourhood_cleansed', hue='room_type')
plt.title("Room Type by Neighborhood")
plt.xlabel("Neighborhood")
plt.ylabel("Count")
plt.xticks(rotation=45)
plt.legend(title='Room Type')
plt.show()

# %%
# Scatter plot for price vs. number of reviews
plt.figure(figsize=(10, 6))
sns.scatterplot(data=listings_df, x='number_of_reviews', y='price', alpha=0.5, color='purple')
plt.title("Price vs. Number of Reviews")
plt.xlabel("Number of Reviews")
plt.ylabel("Price")
plt.xlim(0, 300)  # Limit x-axis for readability
plt.ylim(0, 1000)  # Limit y-axis to $1000 to reduce the effect of outliers
plt.show()

# %%
# Correlation heatmap for selected numeric columns
correlation = listings_df[['price', 'minimum_nights', 'number_of_reviews', 'reviews_per_month', 'availability_365']].corr()

plt.figure(figsize=(8, 6))
sns.heatmap(correlation, annot=True, cmap="coolwarm", center=0)
plt.title("Correlation Matrix of Key Variables")
plt.show()
